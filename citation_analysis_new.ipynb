# %% [markdown]
# # Baltimore Parking/Traffic Citations

# %% [markdown]
# This dataset (Baltimore_Parking_Tickets_2015-01-21.csv) downloaded Jan. 21, 2015 approx. 8:30pm.

# %%
import pandas as pd

# %%
# takes very long time!
df = pd.read_csv('raw_data/Baltimore_Parking_Tickets_2015-01-21.csv',index_col='citation', parse_dates=[10], infer_datetime_format=True)
# Out:
# /Users/Justin/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/io/parsers.py:1159: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
df['violFine_parsed'] = df['violFine'].str.replace("$","").apply(lambda x: float(x))
df['openFine_parsed'] = df['openFine'].str.replace("$","").apply(lambda x: float(x))
df['openPenalty_parsed'] = df['openPenalty'].str.replace("$","").apply(lambda x: float(x))
df['balance_parsed'] = df['balance'].str.replace("$","").apply(lambda x: float(x))

# %%
len(df)
# Out:
# 1004288

# %%
df.head()
# Out:
#                tag expmm  expyy   make state         location  violCode  \
# citation
# 91919465   XNY3041     7     15  DODGE    VA   800 FAYETTE ST        11
# 91919457   1BL8490     4     16  HONDA    MD   800 FAYETTE ST        11
# 91919440    CAKZ79    12     15   FORD    FL   800 FAYETTE ST        11
# 91919432   7BG2327     2     16  CHRYS    MD   700 FAYETTE ST        11
# 91919424  13842388     2     15  INFIN    GA  300 FREMONT AVE        11
#
#                               Description violFine            violDate  \
# citation
# 91919465  Residential Parking Permit Only   $52.00 2015-01-20 14:08:00
# 91919457  Residential Parking Permit Only   $52.00 2015-01-20 14:06:00
# 91919440  Residential Parking Permit Only   $52.00 2015-01-20 14:05:00
# 91919432  Residential Parking Permit Only   $52.00 2015-01-20 14:01:00
# 91919424  Residential Parking Permit Only   $52.00 2015-01-20 13:55:00
#
#          balance  penaltyDate openFine openPenalty noticeDate  \
# citation
# 91919465  $52.00          NaN   $52.00       $0.00        NaN
# 91919457  $52.00          NaN   $52.00       $0.00        NaN
# 91919440  $52.00          NaN   $52.00       $0.00        NaN
# 91919432  $52.00          NaN   $52.00       $0.00        NaN
# 91919424  $52.00          NaN   $52.00       $0.00        NaN
#
#                             ImportDate  violFine_parsed  openFine_parsed  \
# citation
# 91919465  01/21/2015 12:02:00 PM +0000               52               52
# 91919457  01/21/2015 12:02:00 PM +0000               52               52
# 91919440  01/21/2015 12:02:00 PM +0000               52               52
# 91919432  01/21/2015 12:02:00 PM +0000               52               52
# 91919424  01/21/2015 12:02:00 PM +0000               52               52
#
#           openPenalty_parsed  balance_parsed
# citation
# 91919465                   0              52
# 91919457                   0              52
# 91919440                   0              52
# 91919432                   0              52
# 91919424                   0              52

# %% [markdown]
# # By Location

# %%
groupby_loc = df.groupby(df['location'])

# %%
loc_counts = groupby_loc['Description'].count()
loc_revenue = groupby_loc['violFine_parsed'].sum()

loc_counts.sort(inplace=True, ascending=False)
loc_revenue.sort(inplace=True, ascending=False)

# %%
#loc_revenue[:20].to_csv('Top20_Parking_Fine_Blocks.csv')
loc_revenue[:20]
# Out:
# location
# 2600 BLOCK OF GWYNNS FALLS PKW    516560
# 1101 CATON AVE NB                 397920
# REISTERTOWN SB @ DRUID PARK       297375
# WABASH EB @ BELVEDERE             285675
# PULASKI EB @ NORTH POINT          269850
# 4862 ERDMAN AVE W/B               234840
# PULASKI EB @ MORAVIA              228150
# 200 NORTHERN PARKWAY W/B          213680
# 2900 ORLEANS ST. E/B              209120
# 3800 BLOCK OF GREENSPRING AVE     204520
# RUSSELL SB @ BAYARD               200625
# PULASKI HWY EB @ MONUMENT ST      197925
# 4200 SINCLAIR LANE W/B            197640
# NORTHERN WB @ GREENSPRING         195975
# ERDMAN EB @ MACON                 193425
# 4401 EDMONSON AVE E/B             184040
# 1098 CATON AVE S/B                180880
# GWYNNS FALLS WB @ GARRISON        178650
# 4453 SINCLAIR LANE E/B            176920
# 1200 CHARLES ST                   174037
# Name: violFine_parsed, dtype: float64

# %% [markdown]
# There are only 39 locations in Baltimore with ticket counts higher than 10,000:

# %%
loc_counts[loc_counts > 10000].count()
# Out:
# 1

# %%
df['violFine_parsed'].sum()
# Out:
# 48189166.0

# %% [markdown]
# # By Citation Type

# %%
groupby_desc = df.groupby('Description')

citation_desc = pd.DataFrame()

# Total fines for each citation type
citation_desc['fines'] = groupby_desc['violFine_parsed'].sum()

# Number of unique locations each citation type was issued at
citation_desc['unique_locs'] = groupby_desc['location'].nunique()

# Fine type concentration by location
citation_desc['fine_conc_loc'] = (citation_desc['fines'] / citation_desc['unique_locs']).apply(lambda x: round(x,2))

citation_desc.sort('fines',inplace=True,ascending=False)

citation_desc['first_date'] = ''
citation_desc['last_date'] = ''
for row in citation_desc.index:
    # First issue date for each citation type
    citation_desc['first_date'].ix[row] = min(groupby_desc['violDate'].get_group(row))
    # Last issue date for each citation type
    citation_desc['last_date'].ix[row] = max(groupby_desc['violDate'].get_group(row))
# Total date range in years for each citation type
citation_desc['date_range_years'] = (citation_desc['last_date'] - citation_desc['first_date']).astype('timedelta64[D]')/365. 
# Fines per year for each citation type
citation_desc['fines_annual'] = citation_desc['fines']/citation_desc['date_range_years']

citation_desc.head()
#citation_desc.to_csv('citation_desc_date_range_new.csv')
# Out:
# /Users/Justin/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/indexing.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#                                       fines  unique_locs  fine_conc_loc  \
# Description
# Red Light Violation                 6708000          162       41407.41
# All Other Parking Meter Violations  6637646         8012         828.46
# Fixed Speed Camera                  5773840           91       63448.79
# No Stop/Park Street Cleaning        4840482         9501         509.47
# No Stopping/Standing Tow Away Zone  3251300         6912         470.38
#
#                                             first_date           last_date  \
# Description
# Red Light Violation                2002-11-08 12:27:00 2013-04-01 21:23:00
# All Other Parking Meter Violations 2004-06-12 10:44:00 2015-01-20 13:45:00
# Fixed Speed Camera                 2009-11-02 09:30:00 2012-12-31 14:09:00
# No Stop/Park Street Cleaning       2004-09-30 09:02:00 2015-01-20 13:36:00
# No Stopping/Standing Tow Away Zone 2004-10-23 17:15:00 2015-01-20 13:50:00
#
#                                     date_range_years    fines_annual
# Description
# Red Light Violation                        10.402740   644830.129049
# All Other Parking Meter Violations         10.613699   625384.819308
# Fixed Speed Camera                          3.164384  1824633.419913
# No Stop/Park Street Cleaning               10.312329   469387.866631
# No Stopping/Standing Tow Away Zone         10.246575   317306.016043

# %% [markdown]
# # Time Series

# %%
# takes a long time!
df_time = df.fillna(0).set_index(df['violDate'])
# takes a long time!
df_time['ImportDate_parsed'] = pd.to_datetime(df_time['ImportDate'])

# %%
df_time.sort(inplace=True)

# %%
df_time
# Out:
#                           tag expmm  expyy   make state  \
# violDate
# 2002-11-08 12:27:00    KZW022    09      4  TOYOT    MD
# 2004-01-15 19:50:00    LCK831    01      6   CHEV    MD
# 2004-02-29 14:12:00    LSN017    08      5  OTHER    MD
# 2004-03-04 19:03:00    MGC390    01      6  OTHER    MD
# 2004-03-31 12:16:00    MLG502    02      6      0    MD
# 2004-04-10 17:26:00   155M003    11      5      0    MD
# 2004-05-30 14:25:00   155M003    11      5   DODG    MD
# 2004-06-12 10:44:00    CXV499    05      5    BMW    MD
# 2004-07-27 16:54:00   BZK9126    09      4   HOND    NY
# 2004-08-05 19:25:00   106M711    08      5   CHRY    MD
# 2004-08-17 12:00:00    73J526    09      4   FORD    MD
# 2004-08-25 13:34:00   M893472    07      6   CHEV    MD
# 2004-08-27 15:51:00   M324828    08      5   FORD    MD
# 2004-09-11 22:06:00    HKG187    06      6  ACURA    MD
# 2004-09-22 12:22:00   PED4880    04      5   FORD    OH
# 2004-09-30 09:02:00   A086898    06      5  MAZDA    MD
# 2004-10-01 09:11:00    JLT449    06      5   TOYT    MD
# 2004-10-01 19:51:00     TOFEH    08      5   HOND    VA
# 2004-10-01 21:18:00    LEF789    01      5   CHRY    MD
# 2004-10-05 22:10:00  38263L T    11      4   CHEV    MD
# 2004-10-08 09:29:00   132M500    07      5   CHEV    MD
# 2004-10-12 14:03:00    FKK263    08      6   BUIC    MD
# 2004-10-15 10:16:00   RXR4346    06      5   TOYT    NC
# 2004-10-22 11:51:00    KJ551N    04      4   TOYT    NJ
# 2004-10-23 09:04:00   M763456    07      6   NISS    MD
# 2004-10-23 17:15:00    MBY975    08      6    UNK    MD
# 2004-11-06 18:22:00    MWJ64B    07      4   CHEV    NJ
# 2004-11-10 09:05:00    MPC408    05      6   CADI    MD
# 2004-11-26 17:49:00    HHE967    05      6  MAZDA    MD
# 2004-11-29 11:00:00    KFD136    03      6   OLDS    MD
# ...                       ...   ...    ...    ...   ...
# 2015-01-20 13:18:00   9BD7987    12     15  HONDA    MD
# 2015-01-20 13:19:00   5AK8529     8     15   JEEP    MD
# 2015-01-20 13:20:00   7AD2516    12     14  TOYOT    MD
# 2015-01-20 13:21:00   GDH5313     5     15  HONDA    PA
# 2015-01-20 13:22:00   91310HV     5     15  TOYOT    MD
# 2015-01-20 13:23:00   9BC1924     8     15  TOYOT    MD
# 2015-01-20 13:23:00   17979BY     1     15  HONDA    MD
# 2015-01-20 13:25:00   3BF7763     9     15  MITSU    MD
# 2015-01-20 13:26:00    5EXZ49     7     15  MAZDA    MD
# 2015-01-20 13:29:00   4BT6331    11     16    KIA    MD
# 2015-01-20 13:33:00   9AC5016    11     16  VOLKS    MD
# 2015-01-20 13:43:00 2015-01-21 12:02:00
# 2015-01-20 13:45:00 2015-01-21 12:02:00
# 2015-01-20 13:45:00 2015-01-21 12:02:00
# 2015-01-20 13:47:00 2015-01-21 12:02:00
# 2015-01-20 13:49:00 2015-01-21 12:02:00
# 2015-01-20 13:50:00 2015-01-21 12:02:00
# 2015-01-20 13:50:00 2015-01-21 12:02:00
# 2015-01-20 13:55:00 2015-01-21 12:02:00
# 2015-01-20 14:01:00 2015-01-21 12:02:00
# 2015-01-20 14:05:00 2015-01-21 12:02:00
# 2015-01-20 14:06:00 2015-01-21 12:02:00
# 2015-01-20 14:08:00 2015-01-21 12:02:00
#
# [999664 rows x 21 columns]

# %%
df_time['violDate'].ix['2012'].count()
# Out:
# 152174

# %%
# Monthly totals for all citations
df_time['violFine'].resample('M',how='count').plot()

# %%
# Plot top 10 infraction types over time

fig = plt.figure(figsize=[10,8])
for key in citation_desc[:10].index:
    #print key
    df_time['violFine_parsed'][df_time['Description']==key].resample('M', how='count').plot(label=key,grid='off')

xlabel('')
ylabel('Number of Citations')
legend(loc='upper left')

#fig.savefig('Top 10 Monthly Citation Plot 2015-01-21.png', bbox_tight='inches')

# %%
df_time.head()
# Out:
#                           tag expmm  expyy   make state         location  \
# violDate
# 2015-01-20 14:08:00   XNY3041     7     15  DODGE    VA   800 FAYETTE ST
# 2015-01-20 14:06:00   1BL8490     4     16  HONDA    MD   800 FAYETTE ST
# 2015-01-20 14:05:00    CAKZ79    12     15   FORD    FL   800 FAYETTE ST
# 2015-01-20 14:01:00   7BG2327     2     16  CHRYS    MD   700 FAYETTE ST
# 2015-01-20 13:55:00  13842388     2     15  INFIN    GA  300 FREMONT AVE
#
#                      violCode                      Description violFine  \
# violDate
# 2015-01-20 14:08:00        11  Residential Parking Permit Only   $52.00
# 2015-01-20 14:06:00        11  Residential Parking Permit Only   $52.00
# 2015-01-20 14:05:00        11  Residential Parking Permit Only   $52.00
# 2015-01-20 14:01:00        11  Residential Parking Permit Only   $52.00
# 2015-01-20 13:55:00        11  Residential Parking Permit Only   $52.00
#
#                                violDate balance  penaltyDate openFine  \
# violDate
# 2015-01-20 14:08:00 2015-01-20 14:08:00  $52.00            0   $52.00
# 2015-01-20 14:06:00 2015-01-20 14:06:00  $52.00            0   $52.00
# 2015-01-20 14:05:00 2015-01-20 14:05:00  $52.00            0   $52.00
# 2015-01-20 14:01:00 2015-01-20 14:01:00  $52.00            0   $52.00
# 2015-01-20 13:55:00 2015-01-20 13:55:00  $52.00            0   $52.00
#
#                     openPenalty noticeDate                    ImportDate  \
# violDate
# 2015-01-20 14:08:00       $0.00          0  01/21/2015 12:02:00 PM +0000
# 2015-01-20 14:06:00       $0.00          0  01/21/2015 12:02:00 PM +0000
# 2015-01-20 14:05:00       $0.00          0  01/21/2015 12:02:00 PM +0000
# 2015-01-20 14:01:00       $0.00          0  01/21/2015 12:02:00 PM +0000
# 2015-01-20 13:55:00       $0.00          0  01/21/2015 12:02:00 PM +0000
#
#                      violFine_parsed  openFine_parsed  openPenalty_parsed  \
# violDate
# 2015-01-20 14:08:00               52               52                   0
# 2015-01-20 14:06:00               52               52                   0
# 2015-01-20 14:05:00               52               52                   0
# 2015-01-20 14:01:00               52               52                   0
# 2015-01-20 13:55:00               52               52                   0
#
#                      balance_parsed
# violDate
# 2015-01-20 14:08:00              52
# 2015-01-20 14:06:00              52
# 2015-01-20 14:05:00              52
# 2015-01-20 14:01:00              52
# 2015-01-20 13:55:00              52

# %%
# Monthly mobile speed cameras Dec 2012 to Feb 2013 (zero in Jan 2013?)
df_time['violCode'][df_time['Description']=='Mobile Speed Camera'].resample('M',how='count').plot()

# %%
df_time['violFine_parsed'][df_time.index <= pd.to_datetime('21-jan-2013')].sum()
# Out:
# 23873386.0

# %%
df_time[(df_time.index <= pd.to_datetime('21-jan-2013')) & (df_time['balance_parsed']==0)]
# Out:
#                          tag expmm  expyy   make state  \
# violDate
# 2012-09-11 11:28:00  7AP9379    05     13   HOND    MD
# 2012-08-19 16:27:00  HWA3647    02      2  HYUND    PA
# 2012-08-18 12:02:00   01T683    10     14   FORD    MD
# 2012-04-22 18:40:00   8GAL75    04     14   SUZI    MD
# 2012-03-27 21:29:00  HLN4766    06     12   CHEV    PA
# 2011-12-29 13:03:00  1AD9902    11     12   HYUN    MD
# 2011-12-18 16:34:00   DY1893    10     12    ISU    DC
# 2011-11-12 22:54:00   JH1919    04     15   MERZ    MD
# 2011-10-31 16:45:00   8GAL75    04     14   SUZI    MD
# 2011-08-26 09:17:00   1DCN13    02     12   FORD    MD
# 2011-04-26 10:51:00  27933M5    12     15   PONT    MD
# 2011-04-19 18:19:00  4AE3717    01     13   HOND    MD
# 2010-06-13 19:26:00  ECH4208    06     10   TOYT    OH
# 2009-09-04 17:45:00   HPF210    04     16    KIA    MD
# 2008-12-04 20:55:00  DRSMITH    05     13   FORD    MD
# 2008-07-27 19:44:00   3BCD91    10      9   BUIC    MD
#
#                                            location  violCode  \
# violDate
# 2012-09-11 11:28:00  2600 BLOCK OF GWYNNS FALLS PKW        32
# 2012-08-19 16:27:00        PULASKI EB @ NORTH POINT        30
# 2012-08-18 12:02:00   NORTHERN PKWY @ SPRINGLAKE WB        30
# 2012-04-22 18:40:00     EDMONSON AVE EB @ HILTON ST        30
# 2012-03-27 21:29:00                  4100 HILLEN RD        12
# 2011-12-29 13:03:00                   1600 FLEET ST        18
# 2011-12-18 16:34:00   MLK BLVD NB @ WASHINGTON BLVD        30
# 2011-11-12 22:54:00        NORTH AVE WB @ HOWARD ST        30
# 2011-10-31 16:45:00    PRESIDENT ST SB @ FAYETTE ST        30
# 2011-08-26 09:17:00             3900 BENZINGER ROAD         5
# 2011-04-26 10:51:00       7000 REISTERSTOWN RD. S/B        32
# 2011-04-19 18:19:00           6114 HARFORD ROAD N/B        32
# 2010-06-13 19:26:00        PULASKI EB @ NORTH POINT        30
# 2009-09-04 17:45:00     COLD SPRING WB @ LOCH RAVEN        30
# 2008-12-04 20:55:00        PULASKI EB @ NORTH POINT        30
# 2009-09-04 17:45:00 2014-12-26 12:02:00
# 2008-12-04 20:55:00 2013-06-06 11:02:00
# 2008-07-27 19:44:00 2013-05-07 17:41:00
#
# [16 rows x 21 columns]

# %%
df_time[(df_time['ImportDate_parsed'] <= pd.to_datetime('21-jan-2013')) & (df_time['balance_parsed']==0)]
# Out:
# Empty DataFrame
# Columns: [tag, expmm, expyy, make, state, location, violCode, Description, violFine, violDate, balance, penaltyDate, openFine, openPenalty, noticeDate, ImportDate, violFine_parsed, openFine_parsed, openPenalty_parsed, balance_parsed, ImportDate_parsed]
# Index: []
#
# [0 rows x 21 columns]

# %%
df_time_rec = df_time.ix['21-jan-2013':'21-jan-2015']

# %%
total_balance = df_time['balance_parsed'].sum()
total_fines = df_time['violFine_parsed'].ix['21-jan-2013':'21-jan-2015'].sum()
total_pen = df_time['openPenalty_parsed'].ix['21-jan-2013':'21-jan-2015'].sum()

# %%
print total_balance, total_fines, total_pen
# Out:
# 122457404.0 24098830.0 12539524.0

# %%
total_fines+total_pen
# Out:
# 36638354.0

# %%
(total_fines+total_pen)/total_balance
# Out:
# 1.8252984377453603

# %%
total_pen/total_balance
# Out:
# 0.62471074894004386

# %%
df_time['balance_parsed'][df_time['balance_parsed']==0].count()
# Out:
# 357489

# %%
df_time['openFine_parsed'].sum()+df_time['openPenalty_parsed'].sum()
# Out:
# 122410001.0

# %%
df_time['balance_parsed'].sum()
# Out:
# 122457404.0

# %%
df_time['violFine_parsed'].sum()
# Out:
# 47972216.0

# %%
df_time['openPenalty_parsed'].sum()
# Out:
# 91106158.0

# %%
df_time['balance_parsed'].sum() - (df_time['openFine_parsed'].sum()+df_time['openPenalty_parsed'].sum())
# Out:
# 47403.0

# %%
df_time['violFine_parsed'][df_time['balance_parsed']==0].sum()
# Out:
# 16541671.0

# %%
df_time['balance_parsed'].ix['21-jan-2013':'21-jan-2015'].sum()
# Out:
# 20072528.0

# %%
df_time['violFine_parsed'].ix['21-jan-2013':'21-jan-2015'].sum()
# Out:
# 24098830.0

# %%
df_time['openPenalty_parsed'].ix['21-jan-2013':'21-jan-2015'].sum()
# Out:
# 12539524.0

# %%
df_time['openFine_parsed'].ix['21-jan-2013':'21-jan-2015'].sum()
# Out:
# 7526763.0

# %%
df_time['openPenalty_parsed'].ix['21-jan-2013':'21-jan-2015'].sum()+df_time['openFine_parsed'].ix['21-jan-2013':'21-jan-2015'].sum()
# Out:
# 20066287.0

# %%
df_time['balance_parsed'].ix[:'20-jan-2013'].sum()
# Out:
# 102384876.0

# %%
df_time['violFine_parsed'].ix[:'20-jan-2013'].sum()
# Out:
# 23873386.0

# %%
df_time['balance_parsed'].ix[:'20-jan-2013'].sum()/df_time['violFine_parsed'].ix[:'20-jan-2013'].sum()
# Out:
# 4.2886616921453875

# %% [markdown]
# # Last 2 Years

# %%
df_time_2 = df_time.ix['21-jan-2013':]

# %%
df_time_2['violFine_parsed'].resample('M',how='count').plot()

# %%
groupby_desc2 = df_time_2.groupby('Description')

citation_desc2 = pd.DataFrame()

# Total fines for each citation type
citation_desc2['fines'] = groupby_desc2['violFine_parsed'].sum()

# Number of unique locations each citation type was issued at
citation_desc2['unique_locs'] = groupby_desc2['location'].nunique()

# Fine type concentration by location
citation_desc2['fine_conc_loc'] = (citation_desc2['fines'] / citation_desc2['unique_locs']).apply(lambda x: round(x,2))

citation_desc2.sort('fines',inplace=True,ascending=False)

citation_desc2['first_date'] = ''
citation_desc2['last_date'] = ''
for row in citation_desc2.index:
    # First issue date for each citation type
    citation_desc2['first_date'].ix[row] = min(groupby_desc2['violDate'].get_group(row))
    # Last issue date for each citation type
    citation_desc2['last_date'].ix[row] = max(groupby_desc2['violDate'].get_group(row))
# Total date range in years for each citation type
citation_desc2['date_range_years'] = (citation_desc2['last_date'] - citation_desc2['first_date']).astype('timedelta64[D]')/365. 
# Fines per year for each citation type
citation_desc2['fines_annual'] = citation_desc2['fines']/citation_desc2['date_range_years']

citation_desc2
#citation_desc.to_csv('citation_desc_date_range_new.csv')
# Out:
#                                              fines  unique_locs  \
# Description
# All Other Parking Meter Violations         5456709         5279
# No Stop/Park Street Cleaning               3243012         4939
# No Stopping/Standing Tow Away Zone         2672066         4545
# Residential Parking Permit Only            2022634         1991
# No Stopping/Standing Not Tow-Away Zone     1917463         8154
# Expired Tags                               1499827        14162
# No Stop/Park Handicap                      1392336         1144
# Obstruct/Impeding Movement of Pedestrian    900469         3562
# In Transit Zone/Stop                        756146         1723
# All Other Stopping or Parking Violations    704875         6184
# No Stopping//Parking Stadium Event Camden   636888          470
# Commercial Veh/Residence under 20,000 lbs   573048         1328
# Abandonded Vehicle                          570638         1734
# Less Than 15 feet from Fire Hydrant         469910         2493
# Obstruct/Impeding Flow of Traffic           356652         2380
# Passenger Loading Zone                      225563          968
# Mobile Speed Camera                         219000           36
# Commercial Veh/Residence over 20,000 lbs    203612          243
# Exceeding 48 Hours                          119030         2983
# Fire Lane/Handicapped Violation              91176          557
# Red Light Violation                          34125           61
# Blocking Garage or Driveway                  18828          514
# Less 30 from Intersection                    4800          127
# Right on Red                                  3225           16
# No Stop/Stand/Park Cruising                   3161           42
# In Taxicab Stand                              2011           49
# No Stopping or No Parking Pimlico Event       1301           13
# Snow Emergency Route Violation                 308            4
# No Stopping/Parking Stadium Event  33rd        17            1
#
#                                            fine_conc_loc          first_date  \
# Description
# All Other Parking Meter Violations               1033.66 2013-01-21 08:12:00
# No Stop/Park Street Cleaning                      656.61 2013-01-22 07:28:00
# No Stopping/Standing Tow Away Zone                587.91 2013-01-22 08:12:00
# Residential Parking Permit Only                  1015.89 2013-01-21 12:14:00
# No Stopping/Standing Not Tow-Away Zone            235.16 2013-01-21 08:16:00
# Expired Tags                                      105.91 2013-01-21 10:21:00
# No Stop/Park Handicap                            1217.08 2013-01-21 14:08:00
# Obstruct/Impeding Movement of Pedestrian          252.80 2013-01-22 09:32:00
# In Transit Zone/Stop                              438.85 2013-01-22 04:00:00
# All Other Stopping or Parking Violations          113.98 2013-01-21 12:38:00
# No Stop/Park Street Cleaning                       1.994521  1.625961e+06
# No Stopping/Standing Tow Away Zone                 1.994521  1.339703e+06
# Residential Parking Permit Only                    1.997260  1.012704e+06
# No Stopping/Standing Not Tow-Away Zone             1.997260  9.600466e+05
# Expired Tags                                       1.997260  7.509422e+05
# No Stop/Park Handicap                              1.991781  6.990408e+05
# Obstruct/Impeding Movement of Pedestrian           1.994521  4.514714e+05
# In Transit Zone/Stop                               1.994521  3.791117e+05
# All Other Stopping or Parking Violations           1.997260  3.529210e+05
# No Stopping//Parking Stadium Event Camden          1.835616  3.469614e+05
# Commercial Veh/Residence under 20,000 lbs          1.983562  2.888985e+05
# Abandonded Vehicle                                 1.983562  2.876835e+05
# Less Than 15 feet from Fire Hydrant                1.994521  2.356005e+05
# Obstruct/Impeding Flow of Traffic                  1.989041  1.793085e+05
# Passenger Loading Zone                             1.997260  1.129362e+05
# Mobile Speed Camera                                0.112329  1.949634e+06
# Commercial Veh/Residence over 20,000 lbs           1.873973  1.086526e+05
# Exceeding 48 Hours                                 1.986301  5.992545e+04
# Fire Lane/Handicapped Violation                    1.978082  4.609313e+04
# Red Light Violation                                0.063014  5.415489e+05
# Blocking Garage or Driveway                        1.961644  9.598073e+03
# Less 30 from Intersection                         1.931507  2.485106e+03
# Right on Red                                       0.013699  2.354250e+05
# No Stop/Stand/Park Cruising                        1.931507  1.636546e+03
# In Taxicab Stand                                   1.893151  1.062250e+03
# No Stopping or No Parking Pimlico Event            1.736986  7.489984e+02
# Snow Emergency Route Violation                     0.531507  5.794845e+02
# No Stopping/Parking Stadium Event  33rd           0.000000           inf

# %%
# Plot top 10 infraction types over time

fig = plt.figure(figsize=[10,8])
ax1 = plt.subplot(111)

for key in citation_desc2[:10].index:
    #print key
    df_time_2['violFine_parsed'][df_time_2['Description']==key].ix['01-feb-2013':'31-dec-2014'].resample('M', how='count').plot(linewidth=2,label=key,grid='off')

# turn off square border around plot
ax1.spines["top"].set_visible(False)  
ax1.spines["bottom"].set_visible(False)  
ax1.spines["right"].set_visible(False)  
ax1.spines["left"].set_visible(False)

# turn off ticks
ax1.tick_params(axis="both", which="both", bottom="off", top="off",
               labelbottom="on", left="off", right="off", labelleft="on",labelsize=14) 


xlabel('')
ylabel('Number of Citations', fontsize=14)
legend(loc='upper left', fontsize=12)
title('Top 10 Citation Types (by Total Fines)\n 01-Feb-2013 to 31-Dec-2014', fontsize=18)

fig.savefig('output/Top 10 Monthly Citation Plot 2013-02-01 to 2014-12-31.png', bbox_tight='inches')

# %% [markdown]
# # Last 2 Years by Location

# %%
groupby_loc = df_time_2.groupby(df_time_2['location'])

loc_counts = groupby_loc['Description'].count()
loc_revenue = groupby_loc['violFine_parsed'].sum()

loc_counts.sort(inplace=True, ascending=False)
loc_revenue.sort(inplace=True, ascending=False)

# %%
print '\nNumber of locations:', loc_revenue.count()
print 'Number of locations with fines issued greater than $10,000: ', loc_revenue[loc_revenue>=10000].count()
print '% of all locations with fines issued greater than $10,000:', round(100*float(loc_revenue[loc_revenue>=10000].count()) / float(loc_revenue.count()),1)
print '% Revenue generated by locations with fines issued greater than $10,000:', round(100*loc_revenue[loc_revenue>=10000].sum() / loc_revenue.sum(),1),'\n'


loc_revenue.hist(bins=50)
# Out:
# Number of locations: 38597
# Number of locations with fines issued greater than $10,000:  447
# % of all locations with fines issued greater than $10,000: 1.2
# % Revenue generated by locations with fines issued greater than $10,000: 45.8

# %%
loc_revenue[:20].to_csv('output/Top20_Target_locations.csv')

# %%
df_time_2[:-30]
# Out:
#                           tag expmm  expyy   make state             location  \
# violDate
# 2013-01-21 08:12:00   5AR6725    04     14  PONTI    MD      3000 CHARLES ST
# 2013-01-21 08:16:00   2AV0600    07     14  HONDA    MD    900 BONAPARTE AVE
# 2013-01-21 08:40:00   4AS1217    05     14  ACURA    MD       100 CLINTON ST
# 2013-01-21 08:46:00   6AY6243    12     14  NISSA    MD         3400 BANK ST
# 2013-01-21 08:55:00   3AY2738    02     13  OLDSM    MD      400 CONKLING ST
# 2013-01-21 09:17:00   899M381    04     15  OLDSM    MD       400 REDWOOD ST
# 2013-01-21 09:27:00   HPM8797    07     13  HONDA    PA       300 REDWOOD ST
# 2013-01-21 09:34:00   AGY1571    01     14  NISSA    GA    900 SAINT PAUL ST
# 2013-01-21 10:05:00    HPB535    06     13  CHEVR    MD         500 WOLFE ST
# 2013-01-21 10:15:00   6AV2518    08     14  TOYOT    MD         00 BIDDLE ST
# 2013-01-21 10:21:00   26185M2    08     15    GMC    MD    1500 LAKEVIEW AVE
# 2013-01-21 10:35:00   4AW4641    12     12  NISSA    MD         1900 VINE ST
# 2013-01-21 10:41:00   6AX7862    12     12  CADIL    MD   1900 FAIRMOUNT AVE
# 2013-01-21 10:54:00   20348HT    02     14   FORD    MD    2800 HOMEWOOD AVE
# 2013-01-21 11:32:00    7FWY40    06     14  TOYOT    MD     1800 EASTERN AVE
# 2013-01-21 11:41:00   T657590    03     13  CHEVR    MD          700 EDEN ST
# 2013-01-21 11:48:00   YRK9625    06     13   FORD    PA          700 EDEN ST
# 2013-01-21 11:48:00  19248979    01     13  HONDA    NC     1800 EASTERN AVE
# 2013-01-21 12:01:00    1AT655    08      8  CHEVR    MD         800 LIGHT ST
# 2013-01-21 12:01:00    1A1655    11     14   CHEV    MD        E/S 800 LIGHT
# 2013-01-21 12:02:00   4AW1092    12     12   FORD    MD        2600 HAFER ST
# 2013-01-21 12:14:00    AEV439    09     13  CHEVR    SC    900 SAINT PAUL ST
# 2013-01-21 12:25:00   3AW9896    10     12   FORD    MD           0 EUTAW ST
# 2013-01-21 12:31:00   1AV8519    07     14   HYUN    MD        5100 PARK HTS
# 2013-01-21 12:38:00    6CSF67    02     12  MERCU    MD   300 MARTINGALE AVE
# 2013-01-21 13:11:00   6AX6004    10     14  DODGE    MD        1800 FLEET ST
# 2013-01-21 13:33:00    NMR470    03     12  TOYOT    WV          600 EDEN ST
# 2013-01-21 14:08:00   7AL2128    10     13   CHEV    MD       2401 BELAIR RD
# 2013-01-21 15:42:00    60P869    08     14   CINT    MD  E/S 3200 GREENMOUNT
# 2013-01-21 17:15:00   M040048    11     14    GMC    MD     600 PRESIDENT ST
# ...                       ...   ...    ...    ...   ...                  ...
# 2015-01-20 12:45:00   94423CC     9     15  HONDA    MD          600 PACA ST
# 2015-01-20 12:49:00    8CNX57    12     14  TOYOT    MD       3500 BEECH AVE
# 2015-01-20 12:49:00    JMS928    12     15  MAZDA    MD          600 PACA ST
# 2015-01-20 12:51:00   BDP3268     8     15  HYUND    NC      3000 CALVERT ST
# 2015-01-20 12:52:00    7DBL19     5     15  HONDA    MD          600 PACA ST
# 2015-01-20 12:52:00   62484CE     3     16   JEEP    MD    U/B LAFAYETTE AVE
# 2015-01-20 12:54:00   4AZ6632     2     15  NISSA    MD    U/B LAFAYETTE AVE
# 2015-01-20 12:57:00   66033EN     8     15  HYUND    IL      3100 CALVERT ST
# 2015-01-20 12:59:00   4BB1942     5     15    BMW    MD         300 MOUNT ST
# 2015-01-20 13:00:00   90842CE     5     15  HYUND    MD      3100 CALVERT ST
# 2015-01-20 13:01:00   07152CF     9     15  HONDA    MD       5500 BELAIR RD
# 2015-01-20 13:04:00   JNW3513     5     15  NISSA    PA      3100 CALVERT ST
# 2015-01-20 13:04:00    1EFV74     7     16  SCION    MD      5100 ROLAND AVE
# 2015-01-20 13:04:00   12871TL     1     17  TRAIL    MD     300 POPPLETON ST
# 2015-01-20 13:05:00   4CB2746     9     15   FORD    ID          100 32ND ST
# 2015-01-20 13:05:00    ND7315    11     15  SUBAR    WV    100 LAFAYETTE AVE
# 2015-01-20 13:06:00    4CMH23     1     16  CHEVR    MD       5500 BELAIR RD
# 2015-01-20 13:06:00    3FWT24     5     16  HONDA    MD     300 POPPLETON ST
# 2015-01-20 13:06:00   4MYSONS    10     16  NISSA    MD         U/B MOUNT ST
# 2015-01-20 13:07:00   V245498    11     15  NISSA    IL      3100 CALVERT ST
# 2015-01-20 13:07:00   6BC1837    12     15    BMW    MD      5100 ROLAND AVE
# 2015-01-20 13:08:00   9AT1614     7     15  CHEVR    MD     300 POPPLETON ST
# 2015-01-20 13:08:00   A240779     5     15  LINCO    MD    2600 MARYLAND AVE
# 2015-01-20 13:09:00    LRD868     9     15  HONDA    MD      5100 ROLAND AVE
# 2015-01-20 13:12:00   03080CF    11     15  HONDA    MD          U/B 22ND ST
# 2015-01-20 13:12:00   7BD9888     7     15  TOYOT    MD      3200 ST PAUL ST
# 2015-01-20 13:14:00   6BG7778    11     15  TOYOT    MD      5100 ROLAND AVE
# 2015-01-20 13:15:00   9BK3957     4     16  CHEVR    MD   1316 EDMONDSON AVE
# 2015-01-20 13:17:00    MVL600     7     16  ACURA    MD      5100 ROLAND AVE
# 2015-01-20 13:17:00    67L907     9     15  CHEVR    MD          U/B 23RD ST
#
#                      violCode                               Description  \
# violDate
# 2013-01-21 08:12:00        18        All Other Parking Meter Violations
# 2013-01-21 08:16:00        12    No Stopping/Standing Not Tow-Away Zone
# 2015-01-20 13:09:00        18        All Other Parking Meter Violations
# 2015-01-20 13:12:00        18        All Other Parking Meter Violations
# 2015-01-20 13:12:00        18        All Other Parking Meter Violations
# 2015-01-20 13:14:00        18        All Other Parking Meter Violations
# 2015-01-20 13:15:00        27              No Stop/Park Street Cleaning
# 2015-01-20 13:17:00        18        All Other Parking Meter Violations
# 2015-01-20 13:17:00        18        All Other Parking Meter Violations
#
#                     violFine            violDate         ...          \
# violDate                                                 ...
# 2013-01-21 08:12:00   $32.00 2013-01-21 08:12:00         ...
# 2013-01-21 08:16:00   $32.00 2013-01-21 08:16:00         ...
# 2013-01-21 08:40:00   $32.00 2013-01-21 08:40:00         ...
# 2013-01-21 08:46:00   $32.00 2013-01-21 08:46:00         ...
# 2013-01-21 08:55:00   $32.00 2013-01-21 08:55:00         ...
# 2013-01-21 09:17:00   $32.00 2013-01-21 09:17:00         ...
# 2013-01-21 09:27:00   $32.00 2013-01-21 09:27:00         ...
# 2013-01-21 09:34:00   $32.00 2013-01-21 09:34:00         ...
# 2013-01-21 10:05:00   $32.00 2013-01-21 10:05:00         ...
# 2013-01-21 10:15:00   $32.00 2013-01-21 10:15:00         ...
# 2013-01-21 10:21:00   $32.00 2013-01-21 10:21:00         ...
# 2013-01-21 10:35:00   $32.00 2013-01-21 10:35:00         ...
# 2013-01-21 10:41:00   $32.00 2013-01-21 10:41:00         ...
# 2013-01-21 10:54:00   $32.00 2013-01-21 10:54:00         ...
# 2013-01-21 11:32:00   $32.00 2013-01-21 11:32:00         ...
# 2013-01-21 11:41:00   $32.00 2013-01-21 11:41:00         ...
# 2013-01-21 11:48:00   $32.00 2013-01-21 11:48:00         ...
# 2013-01-21 11:48:00   $32.00 2013-01-21 11:48:00         ...
# 2013-01-21 12:01:00   $32.00 2013-01-21 12:01:00         ...
# 2013-01-21 12:01:00   $32.00 2013-01-21 12:01:00         ...
# 2013-01-21 12:02:00   $32.00 2013-01-21 12:02:00         ...
# 2013-01-21 12:14:00   $52.00 2013-01-21 12:14:00         ...
# 2013-01-21 12:25:00   $32.00 2013-01-21 12:25:00         ...
# 2013-01-21 12:31:00   $32.00 2013-01-21 12:31:00         ...
# 2013-01-21 12:38:00   $32.00 2013-01-21 12:38:00         ...
# 2013-01-21 13:11:00   $32.00 2013-01-21 13:11:00         ...
# 2013-01-21 13:33:00   $32.00 2013-01-21 13:33:00         ...
# 2013-01-21 14:08:00  $502.00 2013-01-21 14:08:00         ...
# 2013-01-21 15:42:00   $32.00 2013-01-21 15:42:00         ...
# 2013-01-21 17:15:00   $32.00 2013-01-21 17:15:00         ...
# ...                      ...                 ...         ...
# 2015-01-20 12:45:00   $52.00 2015-01-20 12:45:00         ...
# 2015-01-20 12:49:00   $32.00 2015-01-20 12:49:00         ...
# 2015-01-20 12:49:00   $52.00 2015-01-20 12:49:00         ...
# 2015-01-20 12:51:00   $52.00 2015-01-20 12:51:00         ...
# 2015-01-20 12:52:00   $52.00 2015-01-20 12:52:00         ...
# 2015-01-20 12:52:00 2015-01-21 12:02:00
# 2015-01-20 12:52:00 2015-01-21 12:02:00
# 2015-01-20 12:54:00 2015-01-21 12:02:00
# 2015-01-20 12:57:00 2015-01-21 12:02:00
# 2015-01-20 12:59:00 2015-01-21 12:02:00
# 2015-01-20 13:00:00 2015-01-21 12:02:00
# 2015-01-20 13:01:00 2015-01-21 12:02:00
# 2015-01-20 13:04:00 2015-01-21 12:02:00
# 2015-01-20 13:04:00 2015-01-21 12:02:00
# 2015-01-20 13:04:00 2015-01-21 12:02:00
# 2015-01-20 13:05:00 2015-01-21 12:02:00
# 2015-01-20 13:05:00 2015-01-21 12:02:00
# 2015-01-20 13:06:00 2015-01-21 12:02:00
# 2015-01-20 13:06:00 2015-01-21 12:02:00
# 2015-01-20 13:06:00 2015-01-21 12:02:00
# 2015-01-20 13:07:00 2015-01-21 12:02:00
# 2015-01-20 13:07:00 2015-01-21 12:02:00
# 2015-01-20 13:08:00 2015-01-21 12:02:00
# 2015-01-20 13:08:00 2015-01-21 12:02:00
# 2015-01-20 13:09:00 2015-01-21 12:02:00
# 2015-01-20 13:12:00 2015-01-21 12:02:00
# 2015-01-20 13:12:00 2015-01-21 12:02:00
# 2015-01-20 13:14:00 2015-01-21 12:02:00
# 2015-01-20 13:15:00 2015-01-21 12:02:00
# 2015-01-20 13:17:00 2015-01-21 12:02:00
# 2015-01-20 13:17:00 2015-01-21 12:02:00
#
# [515488 rows x 21 columns]

# %%
red_orange = '#FF3300'

fig = plt.figure(figsize=[6,4])
ax1 = plt.subplot(111)
plot(df_time_2.resample('M', how='count').index,
     df_time_2['tag'][df_time_2['openFine_parsed']==0].resample('M', how='count')/df_time_2['tag'].resample('M', how='count'),
     linewidth=2, color=red_orange)

# turn off square border around plot
ax1.spines["top"].set_visible(False)  
ax1.spines["bottom"].set_visible(False)  
ax1.spines["right"].set_visible(False)  
ax1.spines["left"].set_visible(False)

plt.ylim([0,1])
plt.xticks(rotation=45)
# turn off ticks
ax1.tick_params(axis="both", which="both", bottom="off", top="off",
               labelbottom="on", left="off", right="off", labelleft="on",labelsize=14)

title('% Monthly Citations Records With No Open Balance\n', fontsize=16)

# %%
red_orange = '#FF3300'

fig = plt.figure(figsize=[8,6])
ax1 = plt.subplot(111)
plot(df_time_2.resample('M', how='count').index,
     df_time_2['balance_parsed'][df_time_2['violFine_parsed']>0].resample('M', how='sum')/df_time_2['violFine_parsed'].resample('M', how='sum'),
     linewidth=2, color=red_orange)

# turn off square border around plot
ax1.spines["top"].set_visible(False)  
ax1.spines["bottom"].set_visible(False)  
ax1.spines["right"].set_visible(False)  
ax1.spines["left"].set_visible(False)

plt.ylim([0,1])
plt.xticks(rotation=45)
# turn off ticks
ax1.tick_params(axis="both", which="both", bottom="off", top="off",
               labelbottom="on", left="off", right="off", labelleft="on",labelsize=14)

title('% Monthly Citations Records With No Open Balance\n', fontsize=18)

# %%
df_time_2.resample('M', how='count').index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2013-01-31, ..., 2015-01-31]
# Length: 25, Freq: M, Timezone: None
